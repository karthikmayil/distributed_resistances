# 31    341.80800    247.68700   0.230890
# 32    352.43700    255.38900   0.238335
# 33    363.04700    263.07800   0.245781
# 34    373.63900    270.75300   0.253226
# 35    384.21200    278.41500   0.260672
# 36    394.76800    286.06400   0.268118
# 37    405.30500    293.70000   0.275563
# 38    415.82500    301.32200   0.283009
# 39    426.32300    308.93000   0.290455
# 40    436.80000    316.52200   0.297900
# 41    447.25500    324.09800   0.305346
# 42    457.68800    331.65800   0.312791
# 43    468.10100    339.20400   0.320237
# 44    478.49400    346.73500   0.327683
# 45    488.86500    354.25000   0.335128
# 46    499.21100    361.74700   0.342574
# 47    509.52500    369.22100   0.350020
# 48    519.79600    376.66400   0.357465
# 49    530.02200    384.07400   0.364911
# 50    540.20200    391.45100   0.372356
# 51    550.32500    398.78600   0.379802
# 52    560.36000    406.05800   0.387248
# 53    570.24800    413.22300   0.394693
# 54    579.88100    420.20400   0.402139
# 55    589.04200    426.84200   0.409585
# 56          NaN          NaN   0.409810

# %%
fig,axs = pplt.subplots(ncols=2,nrows=1,sharex=False,sharey=False)

for i in range(4):
    filepath_TVPT = f'0.5C/{i}/Time_Voltage_Position.txt'
    TVPT = pd.read_csv(filepath_TVPT,delim_whitespace=True,skiprows=[1])
    t = TVPT.Time.unique()[-3]
    tdf = TVPT.loc[TVPT.Time==t]
    
    ax=axs[0]
    ax.plot(tdf.Position.values[-6:],tdf.Solid_Conc.values[-6:],'-o')
    
    filepath_TVT = f'0.5C/{i}/Time_Voltage.txt'
    TVT = pd.read_csv(filepath_TVT,delim_whitespace=True,skiprows=[1])
    
    ax=axs[1]
    ax.plot(TVT.Time.values,TVT.Voltage.values,'-')

axs[1].format(ylabel='Voltage',xlabel='Time')
axs[0].format(ylabel='x in LixNMC',xlabel='Position')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-60d2c093384c> in <module>
#       8
#       9     ax=axs[0]
# ---> 10     ax.plot(tdf.Position.values[-6:],tdf.Solid_Conc.values[-6:],'-o')
#      11
#      12     filepath_TVT = f'0.5C/{i}/Time_Voltage.txt'
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Position'
# Figure(nrows=1, ncols=2, refwidth=2.5)

# %%
t = TVPT.Time.unique()[-3]

# %%
tdf = TVPT.loc[TVPT.Time==t]

# %%
fig,ax = pplt.subplots()

ax.plot(tdf.Position.values[-6:],tdf.Solid_Conc.values[-6:],'-o')
ax.format(ylabel='x in LixNMC',xlabel='Position')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %%
filepath = '0.5C/0/Time_Voltage.txt'

TVT = pd.read_csv(filepath,delim_whitespace=True,skiprows=[1])

# %%
fig,ax = pplt.subplots()

ax.plot(TVT.Time.values,TVT.Voltage.values,'-')
ax.format(ylabel='Voltage',xlabel='Time')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)
